# %% [markdown]
# ---
# **Script for Image and Video Colorization**
#
# ---
#
# **David Norman Díaz Estrada**
#
# davidnd@stud.ntnu.no
#
#
# This script contains 3 main sections:
# **1) Load Functions for Video Clorization Framework.**
#
# **2) Video Colorization Example.**
#
# **3) Image Colorization Example.**
#
# In order to run sections 2 or 3, ensure you have ran section 1 first. In sections 2 and 3 you can select any of the 5 trained models and run it for either image or video colorization.

# %% [markdown]
# Check current GPU:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Nov 19 02:16:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Check Available RAM:

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# Mount gdrive:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ---
# **SECTION 1. Load Functions for Video Colorization Framework**
#
# ---

# %% [markdown]
# Import required Libraries for the networks:

# %%
import tensorflow as tf
print("Tensorflow version: ",tf.__version__)

from keras.layers import Conv2D, UpSampling2D, Input
from keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, gray2rgb
from skimage.transform import resize
from skimage.io import imsave

import numpy as np
print("numpy version: ",np.__version__)
import keras
print("keras version: ",keras.__version__)

import os
# Out:
# Tensorflow version:  2.7.0
# numpy version:  1.19.5
# keras version:  2.7.0

# %% [markdown]
# Function to load basemodel (Backbone) and trained model:

# %%
def loadcolorizer(selectedModel,M1_path,M2_path,M3_path,M4_path,M5_path):


  if selectedModel>=1 and selectedModel <=5: #Ensure user selects valid model

    #----------------------------------------------------------------------------------
    if selectedModel>=1 and selectedModel <=4: #Models 1,2,3,4 use VGG16 as the backbone
    #----------------------------------------------------------------------------------
      print("Loading backbone for model: M",selectedModel)
      from keras.applications.vgg16 import VGG16
      vggmodel = VGG16()
      print("VGG16 loaded")

      #----------------------------------------------------------------------------------
      if selectedModel==1: #Model 1 uses VGG16 up to the 22 layer
      #----------------------------------------------------------------------------------
        #Create a basemodel  without the last layers of original VGG16 architecture:
        basemodel = Sequential() 
        for i, layer in enumerate(vggmodel.layers):
            if i<22:          #Only up to 22th layer of size (None, 4096), (it's the last layer before dense layer of predictions)
              basemodel.add(layer)
        # show a summary of the base model
        print("[INFO] summary for base model...")
        basemodel.summary()

        #load the trained model:
        print("-"*40)
        print("Loading M1 trained model")
        print("-"*40)
        trained_Model_Path=M1_path
      #----------------------------------------------------------------------------------
      else: #Model 2,3,4 use VGG16 up to the 19 layer
      #----------------------------------------------------------------------------------
        #Create a basemodel  without the last layers of original VGG16 architecture:
        basemodel = Sequential() 
        for i, layer in enumerate(vggmodel.layers):
            if i<19:          #Only up to 19th layer to include feature extraction only
              basemodel.add(layer)
        # show a summary of the base model
        print("[INFO] summary for base model...")
        basemodel.summary()

        #load the trained model:
        print("-"*40)

        if selectedModel==2:
          print("Loading M2 trained model")
          trained_Model_Path=M2_path
        if selectedModel==3:
          print("Loading M3 trained model")
          trained_Model_Path=M3_path
        if selectedModel==4:
          print("Loading M4 trained model")
          trained_Model_Path=M4_path

        print("-"*40)
    #----------------------------------------------------------------------------------
    elif selectedModel==5: #model 5 uses resnet50 as the backbone
    #----------------------------------------------------------------------------------
      print("Loading backbone for model: M5")
      from tensorflow.keras.applications import ResNet50
      print("ResNet50 loaded")

      basemodel = ResNet50(weights="imagenet", include_top=False,
      input_tensor=Input(shape=(224, 224, 3)))
      # show a summary of the base model
      print("[INFO] summary for base model...")
      print(basemodel.summary())

      print("-"*40)
      print("Loading M5 trained model")
      print("-"*40)
      trained_Model_Path=M5_path

    #--------------------------------------------------------------------------------
    # Load the trained model
    #--------------------------------------------------------------------------------
    print("[INFO] summary for trained model...")
    model = tf.keras.models.load_model(trained_Model_Path,
                                      custom_objects=None,
                                      compile=True)
    model.summary()

    return [model,basemodel]
  else:
    print("Select a valid model: 1,2,3,4,5 ")

# %% [markdown]
# Import libraries required for video processing:

# %%
import cv2
print("OpenCV version: ",cv2.__version__)
import numpy as np
import glob
from time import time
import os
# Out:
# OpenCV version:  4.1.2

# %% [markdown]
# Function to extract all frames from video and save in a given folder:

# %%
def extractFrames(original_video_path):
  # this function extracts all frames from a given video (maximum 1000 frames)
  # it saves frames in following order: (001,002,003... 010,020,100,200...1000)

  print("Extracting frames from video...")
  video = cv2.VideoCapture(original_video_path)
  success,image = video.read()

  #get the number of frames per second of original video(FPS):
  fps = int(video.get(cv2.CAP_PROP_FPS))
  print("Frames per Second: "+str(fps))
  #get total number of frames in video:
  totalFrames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
  print("Total frames: "+str(totalFrames))
  #compute time lenght of video:
  videoTimeSeconds=totalFrames/fps
  print("Video Lenght: "+str(videoTimeSeconds)+" seconds")

  if totalFrames<=1000:
    count = 1
    while success:
      if count<10:  frameNmbr='00'+str(count)
      if count>=10 and count<100: frameNmbr='0'+str(count)
      if count>=100 and count<=1000: frameNmbr=str(count)  
      #print(frameNmbr) 

      #cv2.imwrite("/content/videoFrames2/frame%s.jpg" % frameNmbr, image)     # save frame as JPEG file
      framePath=original_frames_path+"/frame"+frameNmbr+".jpg" 
      cv2.imwrite(framePath, image)     # save frame as JPEG file 

      success,image = video.read() #image is type: <class 'numpy.ndarray'> 
      count += 1
  else:
    print("Video has more than 1000 frames, not suitable for demo")

  return fps

# %% [markdown]
# Function to colorize (predict) a folder with images:

# %%
def colorizeFrames(original_frames_path,colorized_frames_path,model,basemodel,selectedModel):
  print("Colorizing frames...")
  # For this cell the I took some inspiration from :
  # https://github.com/bnsreenu/python_for_microscopists/blob/master/092-autoencoder_colorize_transfer_learning_VGG16_V0.1.py

  ############################################
  #Predicting using trained colorization model.
  ############################################

  #contador=1

  files = os.listdir(original_frames_path)
  for idx, file in enumerate(files):
    #try:
      test = img_to_array(load_img(original_frames_path+"/"+file))
      #print("Type: ",type(test), " Shape: ",test.shape)
      #print(test[:,:,0])
      #print("-"*20)
      #print(test[:,:,1])
      #print("-"*20)
      #print(test[:,:,2])
      #print("Type: ",type(test[1,1,0]), " Shape: ",test[:,:,0].shape)


      test = resize(test, (224,224), anti_aliasing=True)
      test*= 1.0/255
      lab = rgb2lab(test)
      l = lab[:,:,0]
      L = gray2rgb(l)
      L = L.reshape((1,224,224,3))
      #print(L.shape)
      basemodel_features = basemodel.predict(L)
      
      if selectedModel==1:
        ab = model.predict([basemodel_features,L])
      if (selectedModel in range(2,6)):
        ab = model.predict(basemodel_features)
      
      
      #print(ab.shape)
      ab = ab*128
      cur = np.zeros((224, 224, 3))
      cur[:,:,0] = l
      cur[:,:,1:] = ab

      #imsave('/content/videoFramesColorized2/'+file, lab2rgb(cur))
      #imsave('/content/testColorized/'+file, lab2rgb(cur))
      imsave(colorized_frames_path+'/'+"m"+str(selectedModel)+"_"+file, lab2rgb(cur))
    #except:
      #print("************An error ocurred")

    #if contador==1: break

# %% [markdown]
# Function to build video from images in folder:

# %%
def buildVideo(fps,colorized_frames_path,selectedModel):
  t1 = time()
  frameSize = (224, 224)
  framesPerSecond=fps
  video_file='colorizedvideo_model'+str(selectedModel)+"_"+str(framesPerSecond)+'fps.mp4'
  out = cv2.VideoWriter(video_file, cv2.VideoWriter_fourcc(*'mp4v'), framesPerSecond, frameSize)

  #################################################
  #Build the video stacking all frames:
  #################################################
  #Access all files in path:
  #files = glob.glob(r'/content/videoFramesColorized2/*.jpg')
  files = glob.glob(colorized_frames_path+'/*.jpg')
  #Sort the files by alphanumeric order:
  files.sort()


  #Now iterate over each image and add it to the video:
  for myfile in files:
      #print('\n'+myfile)
      img = cv2.imread(myfile)
      #print("type: ",type(img),"shape: ",img.shape, " dataType: ",type(img[1,1,0]))
      out.write(img)


  out.release()#finish video writting
  print("Finished writting video")
  t2 = time()
  elapsed = t2 - t1
  print('Elapsed time is %f seconds.' % elapsed)

# %% [markdown]
# ---
# **SECTION 2: Video Colorization Example (step by step):**
#
# ---
#
# The Video colorization framework is summarized in the following steps:
#
# 1) Define path for trained models, input video, and specify the desired colorization model to use (model 1,2,3,4 or 5).
#
# 2) Load the trained model for colorization.
#
# 3) Extract frames from input video.
#
# 4) Colorize frames.
#
# 5) Build video from colorized frames.

# %% [markdown]
# **Step 1):**
#
# Define path for trained models, input video, and specify the desired colorization model to use (model 1,2,3,4 or 5)

# %%
################################################
# Set the paths for each of the trained models: 
################################################
M1_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M1_colorizer_fusionModel_train61-36_val62-53_100epochs_batch8.h5'
M2_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M2_colorizer_train84-92_val63-20__1000epochs_batch16_1000imgs.h5'
M3_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M3_colorizer_train83-73_val65-57__1000epochs_batch16_2000imgs.h5'
M4_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M4_colorizer_train81-37_val63-58__1000epochs_batch16_8000imgs.h5'
M5_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M5_colorizer_train81-28_val62-92__1000epochs_batch16_8000imgs_resnet50.h5'

################################################
# Set paths for video:
################################################

#Set path for original video:
original_video_path="/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/testVideos/interlaken1.mp4"
#Set path to save extracted frames from original video:
original_frames_path="/content/frames_original_interlaken1"#"/content/frames_original"
#Set path to save colorized frames:
colorized_frames_path="/content/frames_colorized_interlaken1_m5"#"/content/frames_colorized"

################################################
# Select Colorization Model:
################################################

#Indicate which model to use for colorization: 1,2,3,4,5 , which correspond to M1,M2,M3,M4,M5, respectively:
selectedModel=5

# %% [markdown]
# **Step 2): Load the trained model for colorization.**
#
# The following function returns the "model" which corresponds to the trained model, and the "basemodel" which corresponds to the pre-trained model for feature extraction (either VGG16 or ResNet50):

# %%
model,basemodel=loadcolorizer(selectedModel,M1_path,M2_path,M3_path,M4_path,M5_path)
# Out:
# Loading backbone for model: M5
# ResNet50 loaded
# [INFO] summary for base model...
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_7[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# ----------------------------------------
# Loading M5 trained model
# ----------------------------------------
# [INFO] summary for trained model...
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 7, 7, 256)         4718848
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 128)         295040
#
#  up_sampling2d_5 (UpSampling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 64)        73792
#
#  up_sampling2d_6 (UpSampling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        18464
#
#  up_sampling2d_7 (UpSampling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 16)        4624
#
#  up_sampling2d_8 (UpSampling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 112, 112, 2)       290
#
#  up_sampling2d_9 (UpSampling  (None, 224, 224, 2)      0
#  2D)
#
# =================================================================
# Total params: 5,111,058
# Trainable params: 5,111,058
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Step 3): Extract frames from the input video.**
#
# This function will return the FPS (frames per second) of the original video, to ensure the colorized video will be built with the same FPS.

# %%
fps=extractFrames(original_video_path)
# Out:
# Extracting frames from video...
# Frames per Second: 30
# Total frames: 455
# Video Lenght: 15.166666666666666 seconds

# %% [markdown]
# **Step 4): Colorize Frames.**

# %%
colorizeFrames(original_frames_path,colorized_frames_path,model,basemodel,selectedModel)
# Out:
# Colorizing frames...
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 245 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 83 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 20 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 99 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 32 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 46 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 47 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 73 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 88 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 45 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 49 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 185 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 66 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 21 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 146 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 53 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 155 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 104 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 144 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 70 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 340 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 132 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 196 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 41 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 197 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 43 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 135 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 33 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 78 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 113 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 249 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 101 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 259 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 17 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 35 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 52 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 156 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 30 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 62 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 77 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 106 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 64 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 91 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 126 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 18 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 84 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 105 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 96 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 59 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 71 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 63 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 54 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# **Step 5): Build video from colorized frames.**

# %%
buildVideo(fps,colorized_frames_path,selectedModel)
# Out:
# Finished writting video
# Elapsed time is 0.421726 seconds.

# %% [markdown]
# ---
# **SECTION 3: Image Colorization Example**
#
# ---

# %%
############################################################
# Set the paths for each of the trained colorization models: 
############################################################
M1_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M1_colorizer_fusionModel_train61-36_val62-53_100epochs_batch8.h5'
M2_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M2_colorizer_train84-92_val63-20__1000epochs_batch16_1000imgs.h5'
M3_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M3_colorizer_train83-73_val65-57__1000epochs_batch16_2000imgs.h5'
M4_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M4_colorizer_train81-37_val63-58__1000epochs_batch16_8000imgs.h5'
M5_path='/content/gdrive/MyDrive/COSI/Semestre3/VideoProcessing/trainedModels/M5_colorizer_train81-28_val62-92__1000epochs_batch16_8000imgs_resnet50.h5'

# %%
#Load the testing images from the Places365 dataset:
# !unzip '/content/gdrive/My Drive/COSI/Semestre3/VideoProcessing/places365_11k/test.zip'
# Out:
# Archive:  /content/gdrive/My Drive/COSI/Semestre3/VideoProcessing/places365_11k/test.zip
#    creating: test/
#   inflating: test/Places365_val_00010248.jpg
#   inflating: test/Places365_val_00010249.jpg
#   inflating: test/Places365_val_00010250.jpg
#   inflating: test/Places365_val_00010251.jpg
#   inflating: test/Places365_val_00010252.jpg
#   inflating: test/Places365_val_00010253.jpg
#   inflating: test/Places365_val_00010254.jpg
#   inflating: test/Places365_val_00010255.jpg
#   inflating: test/Places365_val_00010256.jpg
#   inflating: test/Places365_val_00010257.jpg
#   inflating: test/Places365_val_00010258.jpg
#   inflating: test/Places365_val_00010259.jpg
#   inflating: test/Places365_val_00010260.jpg
#   inflating: test/Places365_val_00010261.jpg
#   inflating: test/Places365_val_00010262.jpg
#   inflating: test/Places365_val_00010263.jpg
#   inflating: test/Places365_val_00010264.jpg
#   inflating: test/Places365_val_00010265.jpg
#   inflating: test/Places365_val_00010266.jpg
#   inflating: test/Places365_val_00010267.jpg
#   inflating: test/Places365_val_00010268.jpg
#   inflating: test/Places365_val_00010269.jpg
#   inflating: test/Places365_val_00010270.jpg
#   inflating: test/Places365_val_00010271.jpg
#   inflating: test/Places365_val_00010272.jpg
#   inflating: test/Places365_val_00010273.jpg
#   inflating: test/Places365_val_00010275.jpg
#   inflating: test/Places365_val_00010276.jpg
#   inflating: test/Places365_val_00010277.jpg
#   inflating: test/Places365_val_00010278.jpg
#   inflating: test/Places365_val_00010279.jpg
#   inflating: test/Places365_val_00010280.jpg
#   inflating: test/Places365_val_00010281.jpg
#   inflating: test/Places365_val_00010282.jpg
#   inflating: test/Places365_val_00010283.jpg
#   inflating: test/Places365_val_00010284.jpg
#   inflating: test/Places365_val_00010285.jpg
#   inflating: test/Places365_val_00010286.jpg
#   inflating: test/Places365_val_00010287.jpg
#   inflating: test/Places365_val_00010288.jpg
#   inflating: test/Places365_val_00010289.jpg
#   inflating: test/Places365_val_00010290.jpg
#   inflating: test/Places365_val_00010291.jpg
#   inflating: test/Places365_val_00010292.jpg
#   inflating: test/Places365_val_00010293.jpg
#   inflating: test/Places365_val_00010295.jpg
#   inflating: test/Places365_val_00010296.jpg
#   inflating: test/Places365_val_00010297.jpg
#   inflating: test/Places365_val_00010298.jpg
#   inflating: test/Places365_val_00010299.jpg
#   inflating: test/Places365_val_00010300.jpg
#   inflating: test/Places365_val_00010301.jpg
#   inflating: test/Places365_val_00010302.jpg
#   inflating: test/Places365_val_00010303.jpg
#   inflating: test/Places365_val_00010304.jpg
#   inflating: test/Places365_val_00010305.jpg
#   inflating: test/Places365_val_00010306.jpg
#   inflating: test/Places365_val_00010307.jpg
#   inflating: test/Places365_val_00010308.jpg
#   inflating: test/Places365_val_00010309.jpg
#   inflating: test/Places365_val_00010310.jpg
#   inflating: test/Places365_val_00010311.jpg
#   inflating: test/Places365_val_00010312.jpg
#   inflating: test/Places365_val_00010313.jpg
#   inflating: test/Places365_val_00010314.jpg
#   inflating: test/Places365_val_00010315.jpg
#   inflating: test/Places365_val_00010316.jpg
#   inflating: test/Places365_val_00010317.jpg
#   inflating: test/Places365_val_00010318.jpg
#   inflating: test/Places365_val_00010319.jpg
#   inflating: test/Places365_val_00010320.jpg
#   inflating: test/Places365_val_00010321.jpg
#   inflating: test/Places365_val_00010322.jpg
#   inflating: test/Places365_val_00010323.jpg
#   inflating: test/Places365_val_00010324.jpg
#   inflating: test/Places365_val_00010325.jpg
#   inflating: test/Places365_val_00010326.jpg
#   inflating: test/Places365_val_00010327.jpg
#   inflating: test/Places365_val_00010328.jpg
#   inflating: test/Places365_val_00010329.jpg
#   inflating: test/Places365_val_00010330.jpg
#   inflating: test/Places365_val_00010331.jpg
#   inflating: test/Places365_val_00010332.jpg
#   inflating: test/Places365_val_00010333.jpg
#   inflating: test/Places365_val_00010334.jpg
#   inflating: test/Places365_val_00010335.jpg
#   inflating: test/Places365_val_00010337.jpg
#   inflating: test/Places365_val_00010338.jpg
#   inflating: test/Places365_val_00010339.jpg
#   inflating: test/Places365_val_00010340.jpg
#   inflating: test/Places365_val_00010341.jpg
#   inflating: test/Places365_val_00010342.jpg
#   inflating: test/Places365_val_00010343.jpg
#   inflating: test/Places365_val_00010345.jpg
#   inflating: test/Places365_val_00010346.jpg
#   inflating: test/Places365_val_00010347.jpg
#   inflating: test/Places365_val_00010349.jpg
#   inflating: test/Places365_val_00010350.jpg
#   inflating: test/Places365_val_00010351.jpg
#   inflating: test/Places365_val_00010352.jpg
#   inflating: test/Places365_val_00010353.jpg
#   inflating: test/Places365_val_00010354.jpg
#   inflating: test/Places365_val_00010355.jpg
#   inflating: test/Places365_val_00010356.jpg
#   inflating: test/Places365_val_00010357.jpg
#   inflating: test/Places365_val_00010358.jpg
#   inflating: test/Places365_val_00010359.jpg
#   inflating: test/Places365_val_00010360.jpg
#   inflating: test/Places365_val_00010361.jpg
#   inflating: test/Places365_val_00010362.jpg
#   inflating: test/Places365_val_00010363.jpg
#   inflating: test/Places365_val_00010364.jpg
#   inflating: test/Places365_val_00010365.jpg
#   inflating: test/Places365_val_00010366.jpg
#   inflating: test/Places365_val_00010367.jpg
#   inflating: test/Places365_val_00010368.jpg
#   inflating: test/Places365_val_00010369.jpg
#   inflating: test/Places365_val_00010370.jpg
#   inflating: test/Places365_val_00010371.jpg
#   inflating: test/Places365_val_00010372.jpg
#   inflating: test/Places365_val_00010373.jpg
#   inflating: test/Places365_val_00010374.jpg
#   inflating: test/Places365_val_00010375.jpg
#   inflating: test/Places365_val_00010377.jpg
#   inflating: test/Places365_val_00010378.jpg
#   inflating: test/Places365_val_00010379.jpg
#   inflating: test/Places365_val_00010380.jpg
#   inflating: test/Places365_val_00010381.jpg
#   inflating: test/Places365_val_00010382.jpg
#   inflating: test/Places365_val_00010383.jpg
#   inflating: test/Places365_val_00010384.jpg
#   inflating: test/Places365_val_00010385.jpg
#   inflating: test/Places365_val_00010386.jpg
#   inflating: test/Places365_val_00010387.jpg
#   inflating: test/Places365_val_00010388.jpg
#   inflating: test/Places365_val_00010389.jpg
#   inflating: test/Places365_val_00010390.jpg
#   inflating: test/Places365_val_00010391.jpg
#   inflating: test/Places365_val_00010392.jpg
#   inflating: test/Places365_val_00010393.jpg
#   inflating: test/Places365_val_00010394.jpg
#   inflating: test/Places365_val_00010395.jpg
#   inflating: test/Places365_val_00010396.jpg
#   inflating: test/Places365_val_00010397.jpg
#   inflating: test/Places365_val_00010398.jpg
#   inflating: test/Places365_val_00010399.jpg
#   inflating: test/Places365_val_00010400.jpg
#   inflating: test/Places365_val_00010401.jpg
#   inflating: test/Places365_val_00010402.jpg
#   inflating: test/Places365_val_00010403.jpg
#   inflating: test/Places365_val_00010404.jpg
#   inflating: test/Places365_val_00010405.jpg
#   inflating: test/Places365_val_00010406.jpg
#   inflating: test/Places365_val_00010407.jpg
#   inflating: test/Places365_val_00010408.jpg
#   inflating: test/Places365_val_00010409.jpg
#   inflating: test/Places365_val_00010410.jpg
#   inflating: test/Places365_val_00010411.jpg
#   inflating: test/Places365_val_00010412.jpg
#   inflating: test/Places365_val_00010413.jpg
#   inflating: test/Places365_val_00010414.jpg
#   inflating: test/Places365_val_00010415.jpg
#   inflating: test/Places365_val_00010416.jpg
#   inflating: test/Places365_val_00010417.jpg
#   inflating: test/Places365_val_00010418.jpg
#   inflating: test/Places365_val_00010419.jpg
#   inflating: test/Places365_val_00010421.jpg
#   inflating: test/Places365_val_00010422.jpg
#   inflating: test/Places365_val_00010423.jpg
#   inflating: test/Places365_val_00010424.jpg
#   inflating: test/Places365_val_00010425.jpg
#   inflating: test/Places365_val_00010426.jpg
#   inflating: test/Places365_val_00010427.jpg
#   inflating: test/Places365_val_00010428.jpg
#   inflating: test/Places365_val_00010429.jpg
#   inflating: test/Places365_val_00010430.jpg
#   inflating: test/Places365_val_00010431.jpg
#   inflating: test/Places365_val_00010432.jpg
#   inflating: test/Places365_val_00010433.jpg
#   inflating: test/Places365_val_00010434.jpg
#   inflating: test/Places365_val_00010435.jpg
#   inflating: test/Places365_val_00010436.jpg
#   inflating: test/Places365_val_00010437.jpg
#   inflating: test/Places365_val_00010438.jpg
#   inflating: test/Places365_val_00010439.jpg
#   inflating: test/Places365_val_00010440.jpg
#   inflating: test/Places365_val_00010441.jpg
#   inflating: test/Places365_val_00010442.jpg
#   inflating: test/Places365_val_00010443.jpg
#   inflating: test/Places365_val_00010444.jpg
#   inflating: test/Places365_val_00010445.jpg
#   inflating: test/Places365_val_00010446.jpg
#   inflating: test/Places365_val_00010447.jpg
#   inflating: test/Places365_val_00010448.jpg
#   inflating: test/Places365_val_00010449.jpg
#   inflating: test/Places365_val_00010450.jpg
#   inflating: test/Places365_val_00010451.jpg
#   inflating: test/Places365_val_00010452.jpg
#   inflating: test/Places365_val_00010453.jpg
#   inflating: test/Places365_val_00010454.jpg
#   inflating: test/Places365_val_00010455.jpg
#   inflating: test/Places365_val_00010456.jpg
#   inflating: test/Places365_val_00010457.jpg
#   inflating: test/Places365_val_00010458.jpg
#   inflating: test/Places365_val_00010459.jpg
#   inflating: test/Places365_val_00010460.jpg
#   inflating: test/Places365_val_00010461.jpg
#   inflating: test/Places365_val_00010462.jpg
#   inflating: test/Places365_val_00010463.jpg
#   inflating: test/Places365_val_00010464.jpg
#   inflating: test/Places365_val_00010465.jpg
#   inflating: test/Places365_val_00010466.jpg
#   inflating: test/Places365_val_00010467.jpg
#   inflating: test/Places365_val_00010468.jpg
#   inflating: test/Places365_val_00010469.jpg
#   inflating: test/Places365_val_00010470.jpg
#   inflating: test/Places365_val_00010471.jpg
#   inflating: test/Places365_val_00010472.jpg
#   inflating: test/Places365_val_00010474.jpg
#   inflating: test/Places365_val_00010476.jpg
#   inflating: test/Places365_val_00010477.jpg
#   inflating: test/Places365_val_00010478.jpg
#   inflating: test/Places365_val_00010479.jpg
#   inflating: test/Places365_val_00010480.jpg
#   inflating: test/Places365_val_00010481.jpg
#   inflating: test/Places365_val_00010482.jpg
#   inflating: test/Places365_val_00010483.jpg
#   inflating: test/Places365_val_00010484.jpg
#   inflating: test/Places365_val_00010485.jpg
#   inflating: test/Places365_val_00010486.jpg
#   inflating: test/Places365_val_00010487.jpg
#   inflating: test/Places365_val_00010488.jpg
#   inflating: test/Places365_val_00010489.jpg
#   inflating: test/Places365_val_00010490.jpg
#   inflating: test/Places365_val_00010491.jpg
#   inflating: test/Places365_val_00010492.jpg
#   inflating: test/Places365_val_00010493.jpg
#   inflating: test/Places365_val_00010494.jpg
#   inflating: test/Places365_val_00010495.jpg
#   inflating: test/Places365_val_00010496.jpg
#   inflating: test/Places365_val_00010497.jpg
#   inflating: test/Places365_val_00010498.jpg
#   inflating: test/Places365_val_00010499.jpg
#   inflating: test/Places365_val_00010500.jpg
#   inflating: test/Places365_val_00010501.jpg
#   inflating: test/Places365_val_00010502.jpg
#   inflating: test/Places365_val_00010503.jpg
#   inflating: test/Places365_val_00010504.jpg
#   inflating: test/Places365_val_00010505.jpg
#   inflating: test/Places365_val_00010506.jpg
#   inflating: test/Places365_val_00010507.jpg
#   inflating: test/Places365_val_00010508.jpg
#   inflating: test/Places365_val_00010509.jpg
#   inflating: test/Places365_val_00010510.jpg
#   inflating: test/Places365_val_00010512.jpg
#   inflating: test/Places365_val_00010513.jpg
#   inflating: test/Places365_val_00010514.jpg
#   inflating: test/Places365_val_00010515.jpg
#   inflating: test/Places365_val_00010516.jpg
#   inflating: test/Places365_val_00010517.jpg
#   inflating: test/Places365_val_00010518.jpg
#   inflating: test/Places365_val_00010519.jpg
#   inflating: test/Places365_val_00010520.jpg
#   inflating: test/Places365_val_00010521.jpg
#   inflating: test/Places365_val_00010522.jpg
#   inflating: test/Places365_val_00010523.jpg
#   inflating: test/Places365_val_00010524.jpg
#   inflating: test/Places365_val_00010525.jpg
#   inflating: test/Places365_val_00010526.jpg
#   inflating: test/Places365_val_00010527.jpg
#   inflating: test/Places365_val_00010528.jpg
#   inflating: test/Places365_val_00010529.jpg
#   inflating: test/Places365_val_00010530.jpg
#   inflating: test/Places365_val_00010531.jpg
#   inflating: test/Places365_val_00010532.jpg
#   inflating: test/Places365_val_00010533.jpg
#   inflating: test/Places365_val_00010534.jpg
#   inflating: test/Places365_val_00010535.jpg
#   inflating: test/Places365_val_00010536.jpg
#   inflating: test/Places365_val_00010537.jpg
#   inflating: test/Places365_val_00010538.jpg
#   inflating: test/Places365_val_00010539.jpg
#   inflating: test/Places365_val_00010540.jpg
#   inflating: test/Places365_val_00010541.jpg
#   inflating: test/Places365_val_00010542.jpg
#   inflating: test/Places365_val_00010543.jpg
#   inflating: test/Places365_val_00010544.jpg
#   inflating: test/Places365_val_00010545.jpg
#   inflating: test/Places365_val_00010546.jpg
#   inflating: test/Places365_val_00010547.jpg
#   inflating: test/Places365_val_00010548.jpg
#   inflating: test/Places365_val_00010549.jpg
#   inflating: test/Places365_val_00010550.jpg
#   inflating: test/Places365_val_00010551.jpg
#   inflating: test/Places365_val_00010552.jpg
#   inflating: test/Places365_val_00010553.jpg
#   inflating: test/Places365_val_00010554.jpg
#   inflating: test/Places365_val_00010555.jpg
#   inflating: test/Places365_val_00010556.jpg
#   inflating: test/Places365_val_00010557.jpg
#   inflating: test/Places365_val_00010558.jpg
#   inflating: test/Places365_val_00010559.jpg
#   inflating: test/Places365_val_00010560.jpg
#   inflating: test/Places365_val_00010561.jpg
#   inflating: test/Places365_val_00010562.jpg
#   inflating: test/Places365_val_00010563.jpg
#   inflating: test/Places365_val_00010565.jpg
#   inflating: test/Places365_val_00010566.jpg
#   inflating: test/Places365_val_00010567.jpg
#   inflating: test/Places365_val_00010568.jpg
#   inflating: test/Places365_val_00010569.jpg
#   inflating: test/Places365_val_00010570.jpg
#   inflating: test/Places365_val_00010571.jpg
#   inflating: test/Places365_val_00010572.jpg
#   inflating: test/Places365_val_00010573.jpg
#   inflating: test/Places365_val_00010574.jpg
#   inflating: test/Places365_val_00010575.jpg
#   inflating: test/Places365_val_00010576.jpg
#   inflating: test/Places365_val_00010577.jpg
#   inflating: test/Places365_val_00010578.jpg
#   inflating: test/Places365_val_00010579.jpg
#   inflating: test/Places365_val_00010580.jpg
#   inflating: test/Places365_val_00010581.jpg
#   inflating: test/Places365_val_00010582.jpg
#   inflating: test/Places365_val_00010583.jpg
#   inflating: test/Places365_val_00010584.jpg
#   inflating: test/Places365_val_00010585.jpg
#   inflating: test/Places365_val_00010586.jpg
#   inflating: test/Places365_val_00010587.jpg
#   inflating: test/Places365_val_00010588.jpg
#   inflating: test/Places365_val_00010589.jpg
#   inflating: test/Places365_val_00010590.jpg
#   inflating: test/Places365_val_00010591.jpg
#   inflating: test/Places365_val_00010592.jpg
#   inflating: test/Places365_val_00010593.jpg
#   inflating: test/Places365_val_00010594.jpg
#   inflating: test/Places365_val_00010595.jpg
#   inflating: test/Places365_val_00010596.jpg
#   inflating: test/Places365_val_00010597.jpg
#   inflating: test/Places365_val_00010598.jpg
#   inflating: test/Places365_val_00010599.jpg
#   inflating: test/Places365_val_00010600.jpg
#   inflating: test/Places365_val_00010601.jpg
#   inflating: test/Places365_val_00010602.jpg
#   inflating: test/Places365_val_00010603.jpg
#   inflating: test/Places365_val_00010604.jpg
#   inflating: test/Places365_val_00010605.jpg
#   inflating: test/Places365_val_00010606.jpg
#   inflating: test/Places365_val_00010607.jpg
#   inflating: test/Places365_val_00010608.jpg
#   inflating: test/Places365_val_00010610.jpg
#   inflating: test/Places365_val_00010611.jpg
#   inflating: test/Places365_val_00010612.jpg
#   inflating: test/Places365_val_00010613.jpg
#   inflating: test/Places365_val_00010614.jpg
#   inflating: test/Places365_val_00010616.jpg
#   inflating: test/Places365_val_00010617.jpg
#   inflating: test/Places365_val_00010618.jpg
#   inflating: test/Places365_val_00010620.jpg
#   inflating: test/Places365_val_00010621.jpg
#   inflating: test/Places365_val_00010622.jpg
#   inflating: test/Places365_val_00010623.jpg
#   inflating: test/Places365_val_00010624.jpg
#   inflating: test/Places365_val_00010625.jpg
#   inflating: test/Places365_val_00010626.jpg
#   inflating: test/Places365_val_00010627.jpg
#   inflating: test/Places365_val_00010628.jpg
#   inflating: test/Places365_val_00010629.jpg
#   inflating: test/Places365_val_00010630.jpg
#   inflating: test/Places365_val_00010631.jpg
#   inflating: test/Places365_val_00010632.jpg
#   inflating: test/Places365_val_00010633.jpg
#   inflating: test/Places365_val_00010634.jpg
#   inflating: test/Places365_val_00010635.jpg
#   inflating: test/Places365_val_00010636.jpg
#   inflating: test/Places365_val_00010637.jpg
#   inflating: test/Places365_val_00010638.jpg
#   inflating: test/Places365_val_00010639.jpg
#   inflating: test/Places365_val_00010640.jpg
#   inflating: test/Places365_val_00010641.jpg
#   inflating: test/Places365_val_00010642.jpg
#   inflating: test/Places365_val_00010643.jpg
#   inflating: test/Places365_val_00010644.jpg
#   inflating: test/Places365_val_00010645.jpg
#   inflating: test/Places365_val_00010646.jpg
#   inflating: test/Places365_val_00010647.jpg
#   inflating: test/Places365_val_00010648.jpg
#   inflating: test/Places365_val_00010649.jpg
#   inflating: test/Places365_val_00010651.jpg
#   inflating: test/Places365_val_00010652.jpg
#   inflating: test/Places365_val_00010653.jpg
#   inflating: test/Places365_val_00010654.jpg
#   inflating: test/Places365_val_00010655.jpg
#   inflating: test/Places365_val_00010656.jpg
#   inflating: test/Places365_val_00010657.jpg
#   inflating: test/Places365_val_00010658.jpg
#   inflating: test/Places365_val_00010659.jpg
#   inflating: test/Places365_val_00010660.jpg
#   inflating: test/Places365_val_00010661.jpg
#   inflating: test/Places365_val_00010662.jpg
#   inflating: test/Places365_val_00010663.jpg
#   inflating: test/Places365_val_00010664.jpg
#   inflating: test/Places365_val_00010665.jpg
#   inflating: test/Places365_val_00010666.jpg
#   inflating: test/Places365_val_00010667.jpg
#   inflating: test/Places365_val_00010668.jpg
#   inflating: test/Places365_val_00010669.jpg
#   inflating: test/Places365_val_00010670.jpg
#   inflating: test/Places365_val_00010671.jpg
#   inflating: test/Places365_val_00010672.jpg
#   inflating: test/Places365_val_00010673.jpg
#   inflating: test/Places365_val_00010675.jpg
#   inflating: test/Places365_val_00010676.jpg
#   inflating: test/Places365_val_00010677.jpg
#   inflating: test/Places365_val_00010678.jpg
#   inflating: test/Places365_val_00010679.jpg
#   inflating: test/Places365_val_00010680.jpg
#   inflating: test/Places365_val_00010681.jpg
#   inflating: test/Places365_val_00010682.jpg
#   inflating: test/Places365_val_00010683.jpg
#   inflating: test/Places365_val_00010684.jpg
#   inflating: test/Places365_val_00010685.jpg
#   inflating: test/Places365_val_00010686.jpg
#   inflating: test/Places365_val_00010687.jpg
#   inflating: test/Places365_val_00010688.jpg
#   inflating: test/Places365_val_00010689.jpg
#   inflating: test/Places365_val_00010690.jpg
#   inflating: test/Places365_val_00010691.jpg
#   inflating: test/Places365_val_00010692.jpg
#   inflating: test/Places365_val_00010693.jpg
#   inflating: test/Places365_val_00010694.jpg
#   inflating: test/Places365_val_00010695.jpg
#   inflating: test/Places365_val_00010697.jpg
#   inflating: test/Places365_val_00010698.jpg
#   inflating: test/Places365_val_00010699.jpg
#   inflating: test/Places365_val_00010700.jpg
#   inflating: test/Places365_val_00010701.jpg
#   inflating: test/Places365_val_00010702.jpg
#   inflating: test/Places365_val_00010703.jpg
#   inflating: test/Places365_val_00010705.jpg
#   inflating: test/Places365_val_00010706.jpg
#   inflating: test/Places365_val_00010707.jpg
#   inflating: test/Places365_val_00010708.jpg
#   inflating: test/Places365_val_00010709.jpg
#   inflating: test/Places365_val_00010710.jpg
#   inflating: test/Places365_val_00010711.jpg
#   inflating: test/Places365_val_00010712.jpg
#   inflating: test/Places365_val_00010713.jpg
#   inflating: test/Places365_val_00010714.jpg
#   inflating: test/Places365_val_00010715.jpg
#   inflating: test/Places365_val_00010716.jpg
#   inflating: test/Places365_val_00010717.jpg
#   inflating: test/Places365_val_00010718.jpg
#   inflating: test/Places365_val_00010719.jpg
#   inflating: test/Places365_val_00010721.jpg
#   inflating: test/Places365_val_00010722.jpg
#   inflating: test/Places365_val_00010723.jpg
#   inflating: test/Places365_val_00010724.jpg
#   inflating: test/Places365_val_00010725.jpg
#   inflating: test/Places365_val_00010726.jpg
#   inflating: test/Places365_val_00010727.jpg
#   inflating: test/Places365_val_00010728.jpg
#   inflating: test/Places365_val_00010729.jpg
#   inflating: test/Places365_val_00010730.jpg
#   inflating: test/Places365_val_00010731.jpg
#   inflating: test/Places365_val_00010732.jpg
#   inflating: test/Places365_val_00010733.jpg
#   inflating: test/Places365_val_00010734.jpg
#   inflating: test/Places365_val_00010735.jpg
#   inflating: test/Places365_val_00010736.jpg
#   inflating: test/Places365_val_00010737.jpg
#   inflating: test/Places365_val_00010738.jpg
#   inflating: test/Places365_val_00010739.jpg
#   inflating: test/Places365_val_00010740.jpg
#   inflating: test/Places365_val_00010741.jpg
#   inflating: test/Places365_val_00010742.jpg
#   inflating: test/Places365_val_00010743.jpg
#   inflating: test/Places365_val_00010744.jpg
#   inflating: test/Places365_val_00010745.jpg
#   inflating: test/Places365_val_00010746.jpg
#   inflating: test/Places365_val_00010747.jpg
#   inflating: test/Places365_val_00010748.jpg
#   inflating: test/Places365_val_00010749.jpg
#   inflating: test/Places365_val_00010750.jpg
#   inflating: test/Places365_val_00010751.jpg
#   inflating: test/Places365_val_00010752.jpg
#   inflating: test/Places365_val_00010753.jpg
#   inflating: test/Places365_val_00010754.jpg
#   inflating: test/Places365_val_00010755.jpg
#   inflating: test/Places365_val_00010756.jpg
#   inflating: test/Places365_val_00010757.jpg
#   inflating: test/Places365_val_00010758.jpg
#   inflating: test/Places365_val_00010759.jpg
#   inflating: test/Places365_val_00010760.jpg
#   inflating: test/Places365_val_00010761.jpg
#   inflating: test/Places365_val_00010762.jpg
#   inflating: test/Places365_val_00010763.jpg
#   inflating: test/Places365_val_00010764.jpg
#   inflating: test/Places365_val_00010765.jpg
#   inflating: test/Places365_val_00010766.jpg
#   inflating: test/Places365_val_00010767.jpg
#   inflating: test/Places365_val_00010768.jpg
#   inflating: test/Places365_val_00010769.jpg
#   inflating: test/Places365_val_00010770.jpg
#   inflating: test/Places365_val_00010771.jpg
#   inflating: test/Places365_val_00010772.jpg
#   inflating: test/Places365_val_00010773.jpg
#   inflating: test/Places365_val_00010774.jpg
#   inflating: test/Places365_val_00010775.jpg
#   inflating: test/Places365_val_00010776.jpg
#   inflating: test/Places365_val_00010777.jpg
#   inflating: test/Places365_val_00010778.jpg
#   inflating: test/Places365_val_00010779.jpg
#   inflating: test/Places365_val_00010780.jpg
#   inflating: test/Places365_val_00010781.jpg
#   inflating: test/Places365_val_00010782.jpg
#   inflating: test/Places365_val_00010783.jpg
#   inflating: test/Places365_val_00010784.jpg
#   inflating: test/Places365_val_00010785.jpg
#   inflating: test/Places365_val_00010786.jpg
#   inflating: test/Places365_val_00010787.jpg
#   inflating: test/Places365_val_00010788.jpg
#   inflating: test/Places365_val_00010789.jpg
#   inflating: test/Places365_val_00010790.jpg
#   inflating: test/Places365_val_00010791.jpg
#   inflating: test/Places365_val_00010792.jpg
#   inflating: test/Places365_val_00010793.jpg
#   inflating: test/Places365_val_00010794.jpg
#   inflating: test/Places365_val_00010795.jpg
#   inflating: test/Places365_val_00010796.jpg
#   inflating: test/Places365_val_00010797.jpg
#   inflating: test/Places365_val_00010798.jpg
#   inflating: test/Places365_val_00010799.jpg
#   inflating: test/Places365_val_00010800.jpg
#   inflating: test/Places365_val_00010801.jpg
#   inflating: test/Places365_val_00010802.jpg
#   inflating: test/Places365_val_00010803.jpg
#   inflating: test/Places365_val_00010804.jpg
#   inflating: test/Places365_val_00010805.jpg
#   inflating: test/Places365_val_00010806.jpg
#   inflating: test/Places365_val_00010807.jpg
#   inflating: test/Places365_val_00010808.jpg
#   inflating: test/Places365_val_00010809.jpg
#   inflating: test/Places365_val_00010810.jpg
#   inflating: test/Places365_val_00010811.jpg
#   inflating: test/Places365_val_00010812.jpg
#   inflating: test/Places365_val_00010813.jpg
#   inflating: test/Places365_val_00010814.jpg
#   inflating: test/Places365_val_00010815.jpg
#   inflating: test/Places365_val_00010816.jpg
#   inflating: test/Places365_val_00010817.jpg
#   inflating: test/Places365_val_00010818.jpg
#   inflating: test/Places365_val_00010819.jpg
#   inflating: test/Places365_val_00010820.jpg
#   inflating: test/Places365_val_00010821.jpg
#   inflating: test/Places365_val_00010822.jpg
#   inflating: test/Places365_val_00010823.jpg
#   inflating: test/Places365_val_00010824.jpg
#   inflating: test/Places365_val_00010825.jpg
#   inflating: test/Places365_val_00010826.jpg
#   inflating: test/Places365_val_00010827.jpg
#   inflating: test/Places365_val_00010828.jpg
#   inflating: test/Places365_val_00010829.jpg
#   inflating: test/Places365_val_00010830.jpg
#   inflating: test/Places365_val_00010831.jpg
#   inflating: test/Places365_val_00010832.jpg
#   inflating: test/Places365_val_00010833.jpg
#   inflating: test/Places365_val_00010834.jpg
#   inflating: test/Places365_val_00010835.jpg
#   inflating: test/Places365_val_00010836.jpg
#   inflating: test/Places365_val_00010837.jpg
#   inflating: test/Places365_val_00010838.jpg
#   inflating: test/Places365_val_00010839.jpg
#   inflating: test/Places365_val_00010840.jpg
#   inflating: test/Places365_val_00010841.jpg
#   inflating: test/Places365_val_00010842.jpg
#   inflating: test/Places365_val_00010843.jpg
#   inflating: test/Places365_val_00010844.jpg
#   inflating: test/Places365_val_00010845.jpg
#   inflating: test/Places365_val_00010846.jpg
#   inflating: test/Places365_val_00010847.jpg
#   inflating: test/Places365_val_00010848.jpg
#   inflating: test/Places365_val_00010849.jpg
#   inflating: test/Places365_val_00010850.jpg
#   inflating: test/Places365_val_00010851.jpg
#   inflating: test/Places365_val_00010852.jpg
#   inflating: test/Places365_val_00010853.jpg
#   inflating: test/Places365_val_00010854.jpg
#   inflating: test/Places365_val_00010855.jpg
#   inflating: test/Places365_val_00010856.jpg
#   inflating: test/Places365_val_00010857.jpg
#   inflating: test/Places365_val_00010858.jpg
#   inflating: test/Places365_val_00010859.jpg
#   inflating: test/Places365_val_00010860.jpg
#   inflating: test/Places365_val_00010861.jpg
#   inflating: test/Places365_val_00010862.jpg
#   inflating: test/Places365_val_00010863.jpg
#   inflating: test/Places365_val_00010864.jpg
#   inflating: test/Places365_val_00010865.jpg
#   inflating: test/Places365_val_00010866.jpg
#   inflating: test/Places365_val_00010867.jpg
#   inflating: test/Places365_val_00010868.jpg
#   inflating: test/Places365_val_00010869.jpg
#   inflating: test/Places365_val_00010870.jpg
#   inflating: test/Places365_val_00010871.jpg
#   inflating: test/Places365_val_00010872.jpg
#   inflating: test/Places365_val_00010873.jpg
#   inflating: test/Places365_val_00010874.jpg
#   inflating: test/Places365_val_00010875.jpg
#   inflating: test/Places365_val_00010876.jpg
#   inflating: test/Places365_val_00010877.jpg
#   inflating: test/Places365_val_00010878.jpg
#   inflating: test/Places365_val_00010879.jpg
#   inflating: test/Places365_val_00010880.jpg
#   inflating: test/Places365_val_00010881.jpg
#   inflating: test/Places365_val_00010882.jpg
#   inflating: test/Places365_val_00010883.jpg
#   inflating: test/Places365_val_00010884.jpg
#   inflating: test/Places365_val_00010885.jpg
#   inflating: test/Places365_val_00010886.jpg
#   inflating: test/Places365_val_00010887.jpg
#   inflating: test/Places365_val_00010888.jpg
#   inflating: test/Places365_val_00010889.jpg
#   inflating: test/Places365_val_00010890.jpg
#   inflating: test/Places365_val_00010891.jpg
#   inflating: test/Places365_val_00010892.jpg
#   inflating: test/Places365_val_00010893.jpg
#   inflating: test/Places365_val_00010894.jpg
#   inflating: test/Places365_val_00010895.jpg
#   inflating: test/Places365_val_00010896.jpg
#   inflating: test/Places365_val_00010897.jpg
#   inflating: test/Places365_val_00010898.jpg
#   inflating: test/Places365_val_00010899.jpg
#   inflating: test/Places365_val_00010900.jpg
#   inflating: test/Places365_val_00010901.jpg
#   inflating: test/Places365_val_00010902.jpg
#   inflating: test/Places365_val_00010903.jpg
#   inflating: test/Places365_val_00010904.jpg
#   inflating: test/Places365_val_00010905.jpg
#   inflating: test/Places365_val_00010906.jpg
#   inflating: test/Places365_val_00010907.jpg
#   inflating: test/Places365_val_00010908.jpg
#   inflating: test/Places365_val_00010909.jpg
#   inflating: test/Places365_val_00010910.jpg
#   inflating: test/Places365_val_00010911.jpg
#   inflating: test/Places365_val_00010912.jpg
#   inflating: test/Places365_val_00010913.jpg
#   inflating: test/Places365_val_00010914.jpg
#   inflating: test/Places365_val_00010915.jpg
#   inflating: test/Places365_val_00010916.jpg
#   inflating: test/Places365_val_00010917.jpg
#   inflating: test/Places365_val_00010918.jpg
#   inflating: test/Places365_val_00010919.jpg
#   inflating: test/Places365_val_00010920.jpg
#   inflating: test/Places365_val_00010921.jpg
#   inflating: test/Places365_val_00010923.jpg
#   inflating: test/Places365_val_00010924.jpg
#   inflating: test/Places365_val_00010925.jpg
#   inflating: test/Places365_val_00010926.jpg
#   inflating: test/Places365_val_00010927.jpg
#   inflating: test/Places365_val_00010928.jpg
#   inflating: test/Places365_val_00010929.jpg
#   inflating: test/Places365_val_00010930.jpg
#   inflating: test/Places365_val_00010931.jpg
#   inflating: test/Places365_val_00010932.jpg
#   inflating: test/Places365_val_00010933.jpg
#   inflating: test/Places365_val_00010935.jpg
#   inflating: test/Places365_val_00010936.jpg
#   inflating: test/Places365_val_00010937.jpg
#   inflating: test/Places365_val_00010938.jpg
#   inflating: test/Places365_val_00010939.jpg
#   inflating: test/Places365_val_00010940.jpg
#   inflating: test/Places365_val_00010941.jpg
#   inflating: test/Places365_val_00010942.jpg
#   inflating: test/Places365_val_00010943.jpg
#   inflating: test/Places365_val_00010944.jpg
#   inflating: test/Places365_val_00010945.jpg
#   inflating: test/Places365_val_00010946.jpg
#   inflating: test/Places365_val_00010947.jpg
#   inflating: test/Places365_val_00010948.jpg
#   inflating: test/Places365_val_00010949.jpg
#   inflating: test/Places365_val_00010950.jpg
#   inflating: test/Places365_val_00010951.jpg
#   inflating: test/Places365_val_00010952.jpg
#   inflating: test/Places365_val_00010953.jpg
#   inflating: test/Places365_val_00010954.jpg
#   inflating: test/Places365_val_00010955.jpg
#   inflating: test/Places365_val_00010956.jpg
#   inflating: test/Places365_val_00010957.jpg
#   inflating: test/Places365_val_00010958.jpg
#   inflating: test/Places365_val_00010959.jpg
#   inflating: test/Places365_val_00010960.jpg
#   inflating: test/Places365_val_00010961.jpg
#   inflating: test/Places365_val_00010962.jpg
#   inflating: test/Places365_val_00010963.jpg
#   inflating: test/Places365_val_00010964.jpg
#   inflating: test/Places365_val_00010965.jpg
#   inflating: test/Places365_val_00010966.jpg
#   inflating: test/Places365_val_00010967.jpg
#   inflating: test/Places365_val_00010968.jpg
#   inflating: test/Places365_val_00010969.jpg
#   inflating: test/Places365_val_00010970.jpg
#   inflating: test/Places365_val_00010971.jpg
#   inflating: test/Places365_val_00010972.jpg
#   inflating: test/Places365_val_00010973.jpg
#   inflating: test/Places365_val_00010974.jpg
#   inflating: test/Places365_val_00010975.jpg
#   inflating: test/Places365_val_00010976.jpg
#   inflating: test/Places365_val_00010977.jpg
#   inflating: test/Places365_val_00010978.jpg
#   inflating: test/Places365_val_00010979.jpg
#   inflating: test/Places365_val_00010980.jpg
#   inflating: test/Places365_val_00010981.jpg
#   inflating: test/Places365_val_00010982.jpg
#   inflating: test/Places365_val_00010983.jpg
#   inflating: test/Places365_val_00010984.jpg
#   inflating: test/Places365_val_00010985.jpg
#   inflating: test/Places365_val_00010986.jpg
#   inflating: test/Places365_val_00010987.jpg
#   inflating: test/Places365_val_00010988.jpg
#   inflating: test/Places365_val_00010989.jpg
#   inflating: test/Places365_val_00010990.jpg
#   inflating: test/Places365_val_00010991.jpg
#   inflating: test/Places365_val_00010992.jpg
#   inflating: test/Places365_val_00010993.jpg
#   inflating: test/Places365_val_00010994.jpg
#   inflating: test/Places365_val_00010995.jpg
#   inflating: test/Places365_val_00010996.jpg
#   inflating: test/Places365_val_00010997.jpg
#   inflating: test/Places365_val_00010998.jpg
#   inflating: test/Places365_val_00010999.jpg
#   inflating: test/Places365_val_00011000.jpg
#   inflating: test/Places365_val_00011001.jpg
#   inflating: test/Places365_val_00011002.jpg
#   inflating: test/Places365_val_00011003.jpg
#   inflating: test/Places365_val_00011004.jpg
#   inflating: test/Places365_val_00011005.jpg
#   inflating: test/Places365_val_00011006.jpg
#   inflating: test/Places365_val_00011007.jpg
#   inflating: test/Places365_val_00011008.jpg
#   inflating: test/Places365_val_00011009.jpg
#   inflating: test/Places365_val_00011010.jpg
#   inflating: test/Places365_val_00011011.jpg
#   inflating: test/Places365_val_00011012.jpg
#   inflating: test/Places365_val_00011013.jpg
#   inflating: test/Places365_val_00011014.jpg
#   inflating: test/Places365_val_00011015.jpg
#   inflating: test/Places365_val_00011016.jpg
#   inflating: test/Places365_val_00011017.jpg
#   inflating: test/Places365_val_00011018.jpg
#   inflating: test/Places365_val_00011019.jpg
#   inflating: test/Places365_val_00011020.jpg
#   inflating: test/Places365_val_00011022.jpg
#   inflating: test/Places365_val_00011023.jpg
#   inflating: test/Places365_val_00011024.jpg
#   inflating: test/Places365_val_00011025.jpg
#   inflating: test/Places365_val_00011026.jpg
#   inflating: test/Places365_val_00011027.jpg
#   inflating: test/Places365_val_00011028.jpg
#   inflating: test/Places365_val_00011029.jpg
#   inflating: test/Places365_val_00011030.jpg
#   inflating: test/Places365_val_00011031.jpg
#   inflating: test/Places365_val_00011032.jpg
#   inflating: test/Places365_val_00011033.jpg
#   inflating: test/Places365_val_00011034.jpg
#   inflating: test/Places365_val_00011035.jpg
#   inflating: test/Places365_val_00011036.jpg
#   inflating: test/Places365_val_00011037.jpg
#   inflating: test/Places365_val_00011038.jpg
#   inflating: test/Places365_val_00011039.jpg
#   inflating: test/Places365_val_00011040.jpg
#   inflating: test/Places365_val_00011041.jpg
#   inflating: test/Places365_val_00011042.jpg
#   inflating: test/Places365_val_00011043.jpg
#   inflating: test/Places365_val_00011044.jpg
#   inflating: test/Places365_val_00011045.jpg
#   inflating: test/Places365_val_00011046.jpg
#   inflating: test/Places365_val_00011047.jpg
#   inflating: test/Places365_val_00011048.jpg
#   inflating: test/Places365_val_00011049.jpg
#   inflating: test/Places365_val_00011050.jpg
#   inflating: test/Places365_val_00011051.jpg
#   inflating: test/Places365_val_00011052.jpg
#   inflating: test/Places365_val_00011053.jpg
#   inflating: test/Places365_val_00011054.jpg
#   inflating: test/Places365_val_00011055.jpg
#   inflating: test/Places365_val_00011056.jpg
#   inflating: test/Places365_val_00011058.jpg
#   inflating: test/Places365_val_00011059.jpg
#   inflating: test/Places365_val_00011060.jpg
#   inflating: test/Places365_val_00011061.jpg
#   inflating: test/Places365_val_00011062.jpg
#   inflating: test/Places365_val_00011063.jpg
#   inflating: test/Places365_val_00011064.jpg
#   inflating: test/Places365_val_00011065.jpg
#   inflating: test/Places365_val_00011066.jpg
#   inflating: test/Places365_val_00011068.jpg
#   inflating: test/Places365_val_00011069.jpg
#   inflating: test/Places365_val_00011070.jpg
#   inflating: test/Places365_val_00011071.jpg
#   inflating: test/Places365_val_00011072.jpg
#   inflating: test/Places365_val_00011073.jpg
#   inflating: test/Places365_val_00011074.jpg
#   inflating: test/Places365_val_00011075.jpg
#   inflating: test/Places365_val_00011076.jpg
#   inflating: test/Places365_val_00011077.jpg
#   inflating: test/Places365_val_00011078.jpg
#   inflating: test/Places365_val_00011079.jpg
#   inflating: test/Places365_val_00011080.jpg
#   inflating: test/Places365_val_00011081.jpg
#   inflating: test/Places365_val_00011082.jpg
#   inflating: test/Places365_val_00011083.jpg
#   inflating: test/Places365_val_00011084.jpg
#   inflating: test/Places365_val_00011085.jpg
#   inflating: test/Places365_val_00011086.jpg
#   inflating: test/Places365_val_00011087.jpg
#   inflating: test/Places365_val_00011088.jpg
#   inflating: test/Places365_val_00011089.jpg
#   inflating: test/Places365_val_00011092.jpg
#   inflating: test/Places365_val_00011093.jpg
#   inflating: test/Places365_val_00011095.jpg
#   inflating: test/Places365_val_00011096.jpg
#   inflating: test/Places365_val_00011097.jpg
#   inflating: test/Places365_val_00011098.jpg
#   inflating: test/Places365_val_00011099.jpg
#   inflating: test/Places365_val_00011100.jpg
#   inflating: test/Places365_val_00011101.jpg
#   inflating: test/Places365_val_00011102.jpg
#   inflating: test/Places365_val_00011103.jpg
#   inflating: test/Places365_val_00011105.jpg
#   inflating: test/Places365_val_00011106.jpg
#   inflating: test/Places365_val_00011107.jpg
#   inflating: test/Places365_val_00011108.jpg
#   inflating: test/Places365_val_00011109.jpg
#   inflating: test/Places365_val_00011110.jpg
#   inflating: test/Places365_val_00011111.jpg
#   inflating: test/Places365_val_00011112.jpg
#   inflating: test/Places365_val_00011113.jpg
#   inflating: test/Places365_val_00011114.jpg
#   inflating: test/Places365_val_00011115.jpg
#   inflating: test/Places365_val_00011116.jpg
#   inflating: test/Places365_val_00011117.jpg
#   inflating: test/Places365_val_00011118.jpg
#   inflating: test/Places365_val_00011119.jpg
#   inflating: test/Places365_val_00011120.jpg
#   inflating: test/Places365_val_00011121.jpg
#   inflating: test/Places365_val_00011122.jpg
#   inflating: test/Places365_val_00011123.jpg
#   inflating: test/Places365_val_00011124.jpg
#   inflating: test/Places365_val_00011125.jpg
#   inflating: test/Places365_val_00011126.jpg
#   inflating: test/Places365_val_00011127.jpg
#   inflating: test/Places365_val_00011128.jpg
#   inflating: test/Places365_val_00011129.jpg
#   inflating: test/Places365_val_00011130.jpg
#   inflating: test/Places365_val_00011131.jpg
#   inflating: test/Places365_val_00011132.jpg
#   inflating: test/Places365_val_00011133.jpg
#   inflating: test/Places365_val_00011134.jpg
#   inflating: test/Places365_val_00011135.jpg
#   inflating: test/Places365_val_00011136.jpg
#   inflating: test/Places365_val_00011137.jpg
#   inflating: test/Places365_val_00011138.jpg
#   inflating: test/Places365_val_00011139.jpg
#   inflating: test/Places365_val_00011140.jpg
#   inflating: test/Places365_val_00011141.jpg
#   inflating: test/Places365_val_00011142.jpg
#   inflating: test/Places365_val_00011143.jpg
#   inflating: test/Places365_val_00011144.jpg
#   inflating: test/Places365_val_00011145.jpg
#   inflating: test/Places365_val_00011146.jpg
#   inflating: test/Places365_val_00011147.jpg
#   inflating: test/Places365_val_00011148.jpg
#   inflating: test/Places365_val_00011149.jpg
#   inflating: test/Places365_val_00011150.jpg
#   inflating: test/Places365_val_00011151.jpg
#   inflating: test/Places365_val_00011152.jpg
#   inflating: test/Places365_val_00011153.jpg
#   inflating: test/Places365_val_00011154.jpg
#   inflating: test/Places365_val_00011155.jpg
#   inflating: test/Places365_val_00011156.jpg
#   inflating: test/Places365_val_00011157.jpg
#   inflating: test/Places365_val_00011158.jpg
#   inflating: test/Places365_val_00011159.jpg
#   inflating: test/Places365_val_00011160.jpg
#   inflating: test/Places365_val_00011161.jpg
#   inflating: test/Places365_val_00011162.jpg
#   inflating: test/Places365_val_00011163.jpg
#   inflating: test/Places365_val_00011164.jpg
#   inflating: test/Places365_val_00011165.jpg
#   inflating: test/Places365_val_00011166.jpg
#   inflating: test/Places365_val_00011167.jpg
#   inflating: test/Places365_val_00011168.jpg
#   inflating: test/Places365_val_00011169.jpg
#   inflating: test/Places365_val_00011170.jpg
#   inflating: test/Places365_val_00011171.jpg
#   inflating: test/Places365_val_00011173.jpg
#   inflating: test/Places365_val_00011174.jpg
#   inflating: test/Places365_val_00011175.jpg
#   inflating: test/Places365_val_00011176.jpg
#   inflating: test/Places365_val_00011177.jpg
#   inflating: test/Places365_val_00011178.jpg
#   inflating: test/Places365_val_00011179.jpg
#   inflating: test/Places365_val_00011180.jpg
#   inflating: test/Places365_val_00011181.jpg
#   inflating: test/Places365_val_00011182.jpg
#   inflating: test/Places365_val_00011183.jpg
#   inflating: test/Places365_val_00011184.jpg
#   inflating: test/Places365_val_00011185.jpg
#   inflating: test/Places365_val_00011186.jpg
#   inflating: test/Places365_val_00011187.jpg
#   inflating: test/Places365_val_00011188.jpg
#   inflating: test/Places365_val_00011189.jpg
#   inflating: test/Places365_val_00011190.jpg
#   inflating: test/Places365_val_00011191.jpg
#   inflating: test/Places365_val_00011192.jpg
#   inflating: test/Places365_val_00011194.jpg
#   inflating: test/Places365_val_00011195.jpg
#   inflating: test/Places365_val_00011196.jpg
#   inflating: test/Places365_val_00011197.jpg
#   inflating: test/Places365_val_00011199.jpg
#   inflating: test/Places365_val_00011200.jpg
#   inflating: test/Places365_val_00011201.jpg
#   inflating: test/Places365_val_00011202.jpg
#   inflating: test/Places365_val_00011203.jpg
#   inflating: test/Places365_val_00011204.jpg
#   inflating: test/Places365_val_00011205.jpg
#   inflating: test/Places365_val_00011206.jpg
#   inflating: test/Places365_val_00011207.jpg
#   inflating: test/Places365_val_00011208.jpg
#   inflating: test/Places365_val_00011209.jpg
#   inflating: test/Places365_val_00011210.jpg
#   inflating: test/Places365_val_00011211.jpg
#   inflating: test/Places365_val_00011212.jpg
#   inflating: test/Places365_val_00011213.jpg
#   inflating: test/Places365_val_00011214.jpg
#   inflating: test/Places365_val_00011216.jpg
#   inflating: test/Places365_val_00011217.jpg
#   inflating: test/Places365_val_00011218.jpg
#   inflating: test/Places365_val_00011219.jpg
#   inflating: test/Places365_val_00011220.jpg
#   inflating: test/Places365_val_00011221.jpg
#   inflating: test/Places365_val_00011222.jpg
#   inflating: test/Places365_val_00011223.jpg
#   inflating: test/Places365_val_00011225.jpg
#   inflating: test/Places365_val_00011226.jpg
#   inflating: test/Places365_val_00011227.jpg
#   inflating: test/Places365_val_00011228.jpg
#   inflating: test/Places365_val_00011229.jpg
#   inflating: test/Places365_val_00011230.jpg
#   inflating: test/Places365_val_00011231.jpg
#   inflating: test/Places365_val_00011233.jpg
#   inflating: test/Places365_val_00011234.jpg
#   inflating: test/Places365_val_00011235.jpg
#   inflating: test/Places365_val_00011237.jpg
#   inflating: test/Places365_val_00011238.jpg
#   inflating: test/Places365_val_00011239.jpg
#   inflating: test/Places365_val_00011240.jpg
#   inflating: test/Places365_val_00011241.jpg
#   inflating: test/Places365_val_00011242.jpg
#   inflating: test/Places365_val_00011243.jpg
#   inflating: test/Places365_val_00011244.jpg
#   inflating: test/Places365_val_00011245.jpg
#   inflating: test/Places365_val_00011246.jpg
#   inflating: test/Places365_val_00011247.jpg
#   inflating: test/Places365_val_00011248.jpg
#   inflating: test/Places365_val_00011249.jpg
#   inflating: test/Places365_val_00011250.jpg
#   inflating: test/Places365_val_00011251.jpg
#   inflating: test/Places365_val_00011252.jpg
#   inflating: test/Places365_val_00011253.jpg
#   inflating: test/Places365_val_00011254.jpg
#   inflating: test/Places365_val_00011255.jpg
#   inflating: test/Places365_val_00011256.jpg
#   inflating: test/Places365_val_00011257.jpg
#   inflating: test/Places365_val_00011258.jpg
#   inflating: test/Places365_val_00011259.jpg
#   inflating: test/Places365_val_00011260.jpg
#   inflating: test/Places365_val_00011261.jpg
#   inflating: test/Places365_val_00011262.jpg
#   inflating: test/Places365_val_00011263.jpg
#   inflating: test/Places365_val_00011264.jpg
#   inflating: test/Places365_val_00011265.jpg
#   inflating: test/Places365_val_00011266.jpg
#   inflating: test/Places365_val_00011267.jpg
#   inflating: test/Places365_val_00011268.jpg
#   inflating: test/Places365_val_00011269.jpg
#   inflating: test/Places365_val_00011270.jpg
#   inflating: test/Places365_val_00011271.jpg
#   inflating: test/Places365_val_00011272.jpg
#   inflating: test/Places365_val_00011273.jpg
#   inflating: test/Places365_val_00011274.jpg
#   inflating: test/Places365_val_00011275.jpg
#   inflating: test/Places365_val_00011276.jpg
#   inflating: test/Places365_val_00011277.jpg
#   inflating: test/Places365_val_00011278.jpg
#   inflating: test/Places365_val_00011279.jpg
#   inflating: test/Places365_val_00011280.jpg
#   inflating: test/Places365_val_00011281.jpg
#   inflating: test/Places365_val_00011282.jpg

# %%
#Colorize images:

selectedModel=4 #select which model to use (1,2,3,4 or 5)
images_path='/content/test' #define path for the test images folder
colorized_images_path='/content/test_colorized' #define path where the colorized images will be saved

model,basemodel=loadcolorizer(selectedModel,M1_path,M2_path,M3_path,M4_path,M5_path) #load the colorizer model
colorizeFrames(images_path,colorized_images_path,model,basemodel,selectedModel) #colorize the images in the specified folder
# Out:
# Loading backbone for model: M 4
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 7s 0us/step
# 553476096/553467096 [==============================] - 7s 0us/step
# VGG16 loaded
# [INFO] summary for base model...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# ----------------------------------------
# Loading M4 trained model
# ----------------------------------------
# [INFO] summary for trained model...
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 7, 7, 256)         1179904
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 128)         295040
#
#  up_sampling2d_5 (UpSampling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 64)        73792
#
#  up_sampling2d_6 (UpSampling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        18464
#
#  up_sampling2d_7 (UpSampling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 16)        4624
#
#  up_sampling2d_8 (UpSampling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 112, 112, 2)       290
#
#  up_sampling2d_9 (UpSampling  (None, 224, 224, 2)      0
#  2D)
#
# =================================================================
# Total params: 1,572,114
# Trainable params: 1,572,114
# Non-trainable params: 0
# _________________________________________________________________
# Colorizing frames...
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 40 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 42 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 28 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1021 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 25 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 230 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 205 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1916 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 68 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 44 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 96 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 200 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 735 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 9 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 37 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 217 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 51 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 216 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 16 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 38 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 311 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 549 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 45 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 58 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 275 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 117 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 185 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 39 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 89 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 201 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 14 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
#Create a zip file that contains the colorized images, so that you can download all of them:
import zipfile
# !zip -r /content/test_colorized.zip /content/test_colorized
# Out:
#   adding: content/test_colorized/ (stored 0%)
#   adding: content/test_colorized/m4_Places365_val_00010939.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010413.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011163.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010951.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010991.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010812.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010502.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010631.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010778.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010662.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011075.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010368.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011241.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010289.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011183.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011218.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010504.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010770.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010572.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010806.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010440.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011160.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010732.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010276.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010994.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010359.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011257.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010532.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011279.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010876.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010565.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011251.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010882.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010554.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010596.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010341.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010935.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010458.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010757.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011134.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011254.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010367.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010781.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010925.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010787.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010702.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010692.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011124.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010514.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010761.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010529.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010973.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010959.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010687.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010896.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011169.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010920.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011129.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011173.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010342.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011213.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011000.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010316.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010481.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010975.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010600.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010679.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010512.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010762.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010607.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010373.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010357.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010363.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010878.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010497.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010727.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011095.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010858.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010635.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010438.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010628.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010421.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010436.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010558.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010828.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011016.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010331.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011009.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011202.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010347.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010402.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010610.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010717.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010566.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010805.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010415.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010526.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010527.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010464.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010888.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010659.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011199.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010774.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010546.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010766.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010624.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010461.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010703.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010445.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010324.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011165.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010278.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010771.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010904.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011078.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010852.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010388.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010270.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010981.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010872.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010562.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010401.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010557.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010693.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010543.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011022.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011152.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011246.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010500.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010375.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010482.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010997.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010823.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010950.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010907.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010569.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011181.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011120.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010430.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010962.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010862.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010518.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011019.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010946.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010800.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010765.jpg (deflated 6%)
#   adding: content/test_colorized/m4_Places365_val_00010489.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010841.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010851.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010724.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010515.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010608.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010955.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010942.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011097.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010665.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010739.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010496.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010644.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011244.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011040.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010707.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011225.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010735.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011103.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010501.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010722.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011070.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011197.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010584.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010561.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010989.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010613.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010443.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010833.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011179.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010911.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011052.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010354.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010685.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010349.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011017.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011151.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010772.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011220.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011138.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010591.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010343.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010937.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010323.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010678.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010457.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010597.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010273.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010737.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010741.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010648.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011180.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010556.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010480.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010944.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010567.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010447.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010364.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010708.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010713.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010503.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010577.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010978.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010483.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010372.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010534.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010478.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010410.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011204.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010651.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010491.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010866.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010333.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011005.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010386.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010419.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011214.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010844.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011157.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010750.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010893.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010804.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011032.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010927.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011159.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010954.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010266.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010684.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010303.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010900.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010446.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010487.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010521.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010370.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011049.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011208.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011002.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011011.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010412.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011278.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010777.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010550.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010668.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011069.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010571.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010811.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010683.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011054.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010356.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010313.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011093.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010533.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010633.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010284.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011037.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010374.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010338.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010960.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010330.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011024.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010723.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010835.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010275.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010879.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010428.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011250.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010380.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010513.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010688.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011020.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011189.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010681.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010469.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010474.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010377.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010397.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010988.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010758.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010616.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011158.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010689.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010507.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010808.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010277.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011156.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010672.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010623.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011018.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010948.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011109.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010745.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011079.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010661.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011108.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010847.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011140.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010267.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010958.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010941.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010933.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010903.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010788.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010940.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011240.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011212.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010379.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010698.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010718.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011043.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010494.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010839.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011170.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011270.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010711.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010352.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010437.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010322.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011089.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011031.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011038.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010801.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010530.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011119.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011149.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010914.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010943.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010528.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010547.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010580.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010985.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010974.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010947.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011217.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010301.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011059.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010697.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011205.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011186.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011171.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010856.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010760.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010472.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010768.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011080.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010728.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010729.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010822.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010961.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010576.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011185.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011099.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011092.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011061.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010444.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010843.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011192.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010753.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011261.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010369.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010416.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010686.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010963.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010749.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010814.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010870.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011262.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010570.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010868.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010834.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010498.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010306.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010490.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010479.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010799.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010889.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011106.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010404.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010894.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010677.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010272.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010667.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010848.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010250.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010645.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010712.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010733.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010468.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010816.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011228.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011190.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011064.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011013.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010996.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010407.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010582.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010982.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011147.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010439.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011269.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010746.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010837.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011006.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010976.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010669.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010627.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010917.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010649.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010782.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010913.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010308.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010516.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010875.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010748.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010317.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011233.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010588.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010448.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011073.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010621.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010586.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010817.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011003.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010251.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010901.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010594.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010986.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011259.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011229.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010652.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011041.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010292.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011128.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011210.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010334.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010269.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010869.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011015.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011194.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010902.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010418.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010611.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010802.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011081.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010417.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011118.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010859.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011234.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010657.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010747.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010912.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010919.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010695.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010928.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010656.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010654.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010918.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010832.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011235.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011153.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010256.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010460.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010283.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010394.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010898.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010618.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010622.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010890.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011084.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010936.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011146.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011063.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010517.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010742.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010471.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011167.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010259.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011258.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011062.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011045.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010653.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011010.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010462.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011207.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010499.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011105.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010620.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011034.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010714.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010825.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010319.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010736.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010423.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011055.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011187.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010630.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010625.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010351.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010318.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010797.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010398.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011162.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010818.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011035.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010595.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010268.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010441.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010520.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010734.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010287.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010252.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011056.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011277.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010885.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011222.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010673.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010358.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010957.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010850.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010254.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011282.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010842.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010332.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011260.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011166.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010495.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011242.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011230.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010956.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010450.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010836.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011047.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011122.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011046.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011100.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010311.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010540.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010263.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010867.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010509.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011110.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010726.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010999.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010293.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011238.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010366.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010709.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010360.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011275.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011012.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010881.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010408.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011255.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011123.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010773.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010830.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010871.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010738.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010831.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010400.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011168.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010838.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011048.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011223.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010339.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011182.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011058.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011111.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010660.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010614.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010754.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011265.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010923.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010790.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010248.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010549.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010257.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010552.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011133.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010265.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010751.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010309.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010638.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010541.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011211.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010545.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010966.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010279.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010849.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011177.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010315.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011273.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010262.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010930.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010452.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010326.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010590.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010884.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010433.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011068.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010253.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010886.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010730.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011029.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011256.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011028.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011083.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010427.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011155.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010779.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010519.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010829.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010451.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010454.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010715.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010535.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011027.jpg (deflated 1%)
# ...
#   adding: content/test_colorized/m4_Places365_val_00010887.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010786.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010980.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010258.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010288.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010399.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010385.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010700.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010449.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010403.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011060.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010845.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010544.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011117.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010470.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011200.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010389.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010291.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010592.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010425.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010281.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010929.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010752.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011044.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010297.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011036.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010798.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010486.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011098.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011082.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010705.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010426.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010559.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010382.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010926.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010605.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010424.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011249.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010589.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010563.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010393.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010312.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010414.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011127.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010261.jpg (deflated 5%)
#   adding: content/test_colorized/m4_Places365_val_00010979.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011076.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011131.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010716.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010476.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010321.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010325.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011221.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010694.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010682.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011112.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010353.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011248.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010776.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011143.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010824.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010763.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010785.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011039.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010873.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011280.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010310.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010395.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011247.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010853.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010555.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010328.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010484.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010945.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00011267.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010432.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010601.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010854.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011030.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010409.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010506.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010459.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010863.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010791.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011264.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00011004.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011132.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011051.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010846.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010861.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010706.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010314.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010538.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010857.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010840.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011226.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010731.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010949.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010769.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010560.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010593.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00011191.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010522.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010710.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010995.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011206.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011188.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011245.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010508.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010932.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011252.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010719.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011025.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010969.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010523.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010524.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010300.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010551.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010568.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010775.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011145.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010826.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011137.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010422.jpg (deflated 4%)
#   adding: content/test_colorized/m4_Places365_val_00010721.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010767.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010525.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011125.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010855.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011201.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011150.jpg (deflated 3%)
#   adding: content/test_colorized/m4_Places365_val_00010860.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010617.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010296.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010675.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010337.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010642.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010690.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011072.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010477.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010362.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010874.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010725.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010987.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010574.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011065.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010327.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010964.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010632.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010264.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010701.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011176.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010280.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010378.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010796.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010670.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010537.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010897.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010411.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011130.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010666.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010699.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010655.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010983.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010764.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010640.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011102.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011115.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011139.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010249.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010384.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010809.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010938.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011271.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010286.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010641.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011263.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010880.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010864.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011113.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011042.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011087.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010260.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010899.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010585.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010992.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010965.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010492.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010984.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010463.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011086.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010921.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011121.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010636.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010998.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010780.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011175.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011142.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010905.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00011184.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010895.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010320.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010456.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010579.jpg (deflated 2%)
#   adding: content/test_colorized/m4_Places365_val_00010387.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00011219.jpg (deflated 1%)
#   adding: content/test_colorized/m4_Places365_val_00010821.jpg (deflated 1%)
